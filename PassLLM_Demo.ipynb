# %% [markdown]
# <a href="https://colab.research.google.com/github/Tzohar/PassLLM/blob/main/PassLLM_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title 1. Setup Environment
# Clone the repository
# !git clone https://github.com/Tzohar/PassLLM.git
# %cd PassLLM

# Install dependencies
# !pip install -r requirements.txt

# %%
# @title 2. Download Model Weights
import os

# Create directory
os.makedirs("models", exist_ok=True)

# Download weights
# !curl -L "https://github.com/Tzohar/PassLLM/releases/download/v1.0.0/PassLLM_LoRA_Weights.pth" -o models/PassLLM_LoRA_Weights.pth

print("Weights downloaded successfully!")

# %%
# @title 3. Input Target Information (target.jsonl)
# @markdown Edit the JSON data below for your target.

target_data = """
{"name": "Marcus Thorne", "birth_year": "1976", "username": "mthorne88", "country": "Canada"}
"""

with open("target.jsonl", "w") as f:
    f.write(target_data.strip())

print("Target info saved to target.jsonl")

# %%
# @title 4. Run PassLLM
# Run the main script
# !python main.py
